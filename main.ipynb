# %%
import requests
import pandas as pd

df = pd.read_csv('wpf_karnataka.csv')

# %%
df.head()
# Out:
#          date     admin1           admin2     market   latitude  longitude  \
# 0  1994-01-15  Karnataka  Bangalore Urban  Bengaluru  12.962299  77.576943
# 1  1994-03-15  Karnataka  Bangalore Urban  Bengaluru  12.962299  77.576943
# 2  1994-04-15  Karnataka  Bangalore Urban  Bengaluru  12.962299  77.576943
# 3  1994-05-15  Karnataka  Bangalore Urban  Bengaluru  12.962299  77.576943
# 4  1994-07-15  Karnataka  Bangalore Urban  Bengaluru  12.962299  77.576943
#
#              category commodity unit priceflag pricetype currency  price  \
# 0  cereals and tubers     Wheat   KG    actual    Retail      INR    7.0
# 1  cereals and tubers     Wheat   KG    actual    Retail      INR    6.5
# 2  cereals and tubers     Wheat   KG    actual    Retail      INR    6.5
# 3  cereals and tubers     Wheat   KG    actual    Retail      INR    4.0
# 4  cereals and tubers     Wheat   KG    actual    Retail      INR    6.8
#
#    usdprice
# 0    0.2231
# 1    0.2073
# 2    0.2073
# 3    0.1275
# ...
